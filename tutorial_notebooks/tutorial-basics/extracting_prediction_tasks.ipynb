# %% [markdown]
# In the below tutorial, we will demonstrate how you can use the
# [ACES](https://eventstreamaces.readthedocs.io/en/latest/) package to extract a prediction task on the MIMIC-IV
# Demo dataset!

# %% [markdown]
# ## Tutorial Set-up

# %%
import os
from pathlib import Path

DEMO_DIR = Path(os.getenv("MEDS_DEMO_DIR", "./demo_output"))

# %% [markdown]
# ### MIMIC-IV Demo Dataset

# %% [markdown]
# You can use the [MIMIC_IV_MEDS](https://github.com/Medical-Event-Data-Standard/MIMIC_IV_MEDS) package to easily download and transform the MIMIC-IV-Demo dataset into MEDS:

# %%
OUTPUT_DIR = DEMO_DIR / "meds/"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# !MEDS_extract-MIMIC_IV root_output_dir=$OUTPUT_DIR do_demo=True do_overwrite=True
# Out:
# [2025-03-22 14:14:00,774][MIMIC_IV_MEDS.__main__][INFO] - Downloading demo data.
# [2025-03-22 14:14:01,448][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/admissions.csv.gz
# [2025-03-22 14:14:02,863][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/d_hcpcs.csv.gz
# [2025-03-22 14:14:07,312][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/d_icd_diagnoses.csv.gz
# [2025-03-22 14:14:09,767][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/d_icd_procedures.csv.gz
# [2025-03-22 14:14:09,906][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/d_labitems.csv.gz
# [2025-03-22 14:14:10,064][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/diagnoses_icd.csv.gz
# [2025-03-22 14:14:10,186][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/drgcodes.csv.gz
# ...

# %% [markdown]
# ## Extracting the Prediction Task

# %% [markdown]
# This task predicts whether the patient will have low _MAP_ values (hypotension) within the next 24 hours,
# given the first 24 hours of their admission to the hospital. To be included, 1) patients must have at
# least one measurement for _MAP_ within the next 24 hours after their admission to the hospital, 2)
# patients must not have shown low _MAP_ values previously, and 3) their length of stay in the hospital must
# be at least 48 hours.
