# %% [markdown]
# In the below tutorial, we will demonstrate how you can use the
# [ACES](https://eventstreamaces.readthedocs.io/en/latest/) package to extract a prediction task on the MIMIC-IV
# Demo dataset!

# %% [markdown]
# ## Tutorial Set-up

# %%
import os
from pathlib import Path

DEMO_DIR = Path(os.getenv("MEDS_DEMO_DIR", "./demo_output"))

# %% [markdown]
# ### MIMIC-IV Demo Dataset

# %% [markdown]
# You can use the [MIMIC_IV_MEDS](https://github.com/Medical-Event-Data-Standard/MIMIC_IV_MEDS) package to easily download and automatically transform the MIMIC-IV-Demo dataset into MEDS:

# %%
OUTPUT_DIR = DEMO_DIR / "meds/"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# !MEDS_extract-MIMIC_IV root_output_dir=$OUTPUT_DIR do_demo=True do_copy=True
# Out:
# [2025-03-25 02:14:37,416][MIMIC_IV_MEDS.__main__][INFO] - Downloading demo data.
# [2025-03-25 02:14:38,293][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/admissions.csv.gz
# [2025-03-25 02:14:39,570][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/d_hcpcs.csv.gz
# [2025-03-25 02:14:45,225][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/d_icd_diagnoses.csv.gz
# [2025-03-25 02:14:48,035][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/d_icd_procedures.csv.gz
# [2025-03-25 02:14:48,165][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/d_labitems.csv.gz
# [2025-03-25 02:14:48,340][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/diagnoses_icd.csv.gz
# [2025-03-25 02:14:48,461][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/drgcodes.csv.gz
# [2025-03-25 02:14:50,354][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/emar.csv.gz
# [2025-03-25 02:14:52,072][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/emar_detail.csv.gz
# [2025-03-25 02:14:52,186][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/hcpcsevents.csv.gz
# [2025-03-25 02:14:57,140][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/labevents.csv.gz
# [2025-03-25 02:14:57,436][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/microbiologyevents.csv.gz
# [2025-03-25 02:14:57,579][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/omr.csv.gz
# [2025-03-25 02:14:57,690][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/patients.csv.gz
# [2025-03-25 02:14:58,899][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/pharmacy.csv.gz
# [2025-03-25 02:15:00,324][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/poe.csv.gz
# [2025-03-25 02:15:00,489][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/poe_detail.csv.gz
# [2025-03-25 02:15:02,043][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/prescriptions.csv.gz
# [2025-03-25 02:15:02,492][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/procedures_icd.csv.gz
# [2025-03-25 02:15:03,086][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/provider.csv.gz
# [2025-03-25 02:15:03,201][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/services.csv.gz
# [2025-03-25 02:15:03,393][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/hosp/transfers.csv.gz
# [2025-03-25 02:15:03,715][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/icu/caregiver.csv.gz
# [2025-03-25 02:15:18,873][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/icu/chartevents.csv.gz
# [2025-03-25 02:15:19,106][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/icu/d_items.csv.gz
# [2025-03-25 02:15:19,482][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/icu/datetimeevents.csv.gz
# [2025-03-25 02:15:19,628][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/icu/icustays.csv.gz
# [2025-03-25 02:15:21,281][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/icu/ingredientevents.csv.gz
# [2025-03-25 02:15:23,165][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/icu/inputevents.csv.gz
# [2025-03-25 02:15:23,570][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/icu/outputevents.csv.gz
# [2025-03-25 02:15:23,794][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/icu/procedureevents.csv.gz
# [2025-03-25 02:15:23,955][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/LICENSE.txt
# [2025-03-25 02:15:24,061][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/README.txt
# [2025-03-25 02:15:24,175][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/SHA256SUMS.txt
# [2025-03-25 02:15:24,292][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/demo_subject_id.csv
# [2025-03-25 02:15:24,471][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/d_labitems_to_loinc.csv
# [2025-03-25 02:15:24,640][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/inputevents_to_rxnorm.csv
# [2025-03-25 02:15:24,789][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/lab_itemid_to_loinc.csv
# [2025-03-25 02:15:24,965][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/meas_chartevents_main.csv
# [2025-03-25 02:15:25,131][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/meas_chartevents_value.csv
# [2025-03-25 02:15:25,284][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/numerics-summary.csv
# [2025-03-25 02:15:25,495][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/outputevents_to_loinc.csv
# [2025-03-25 02:15:25,657][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/proc_datetimeevents.csv
# [2025-03-25 02:15:25,851][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/proc_itemid.csv
# [2025-03-25 02:15:26,001][MIMIC_IV_MEDS.download][INFO] - Downloaded: demo_output/meds/raw_input/waveforms-summary.csv
# [2025-03-25 02:15:26,013][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for icu/caregiver: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/icu/caregiver.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/caregiver.csv.gz
# [2025-03-25 02:15:26,015][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for icu/chartevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/icu/chartevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/chartevents.csv.gz
# [2025-03-25 02:15:26,025][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for icu/procedureevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/icu/procedureevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/procedureevents.csv.gz
# [2025-03-25 02:15:26,027][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for icu/icustays: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/icu/icustays.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/icustays.csv.gz
# [2025-03-25 02:15:26,028][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for icu/outputevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/icu/outputevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/outputevents.csv.gz
# [2025-03-25 02:15:26,029][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for icu/inputevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/icu/inputevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/inputevents.csv.gz
# [2025-03-25 02:15:26,032][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for icu/ingredientevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/icu/ingredientevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/ingredientevents.csv.gz
# [2025-03-25 02:15:26,034][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for icu/d_items: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/icu/d_items.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/d_items.csv.gz
# [2025-03-25 02:15:26,036][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for icu/datetimeevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/icu/datetimeevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/datetimeevents.csv.gz
# [2025-03-25 02:15:26,037][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/d_hcpcs: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/d_hcpcs.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/d_hcpcs.csv.gz
# [2025-03-25 02:15:26,039][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/admissions: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/admissions.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/admissions.csv.gz
# [2025-03-25 02:15:26,041][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/transfers: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/transfers.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/transfers.csv.gz
# [2025-03-25 02:15:26,043][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/emar_detail: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/emar_detail.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/emar_detail.csv.gz
# [2025-03-25 02:15:26,046][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/microbiologyevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/microbiologyevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/microbiologyevents.csv.gz
# [2025-03-25 02:15:26,047][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/emar: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/emar.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/emar.csv.gz
# [2025-03-25 02:15:26,051][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/pharmacy: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/pharmacy.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/pharmacy.csv.gz
# [2025-03-25 02:15:26,054][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/labevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/labevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/labevents.csv.gz
# [2025-03-25 02:15:26,058][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/procedures_icd: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/procedures_icd.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/procedures_icd.csv.gz
# [2025-03-25 02:15:26,059][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/hcpcsevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/hcpcsevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/hcpcsevents.csv.gz
# [2025-03-25 02:15:26,060][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/prescriptions: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/prescriptions.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/prescriptions.csv.gz
# [2025-03-25 02:15:26,062][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/d_labitems: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/d_labitems.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/d_labitems.csv.gz
# [2025-03-25 02:15:26,063][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/poe: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/poe.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/poe.csv.gz
# [2025-03-25 02:15:26,065][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/provider: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/provider.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/provider.csv.gz
# [2025-03-25 02:15:26,066][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/poe_detail: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/poe_detail.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/poe_detail.csv.gz
# [2025-03-25 02:15:26,067][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/omr: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/omr.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/omr.csv.gz
# [2025-03-25 02:15:26,068][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for hosp/services: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/services.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/services.csv.gz
# [2025-03-25 02:15:26,069][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for numerics-summary: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/numerics-summary.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/numerics-summary.csv
# [2025-03-25 02:15:26,070][MIMIC_IV_MEDS.pre_MEDS][INFO] - Skipping README @ /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/README.txt as no compatible dataframe file was found.
# [2025-03-25 02:15:26,070][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for outputevents_to_loinc: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/outputevents_to_loinc.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/outputevents_to_loinc.csv
# [2025-03-25 02:15:26,071][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for lab_itemid_to_loinc: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/lab_itemid_to_loinc.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/lab_itemid_to_loinc.csv
# [2025-03-25 02:15:26,072][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for meas_chartevents_main: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/meas_chartevents_main.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/meas_chartevents_main.csv
# [2025-03-25 02:15:26,073][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for inputevents_to_rxnorm: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/inputevents_to_rxnorm.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/inputevents_to_rxnorm.csv
# [2025-03-25 02:15:26,074][MIMIC_IV_MEDS.pre_MEDS][INFO] - Skipping LICENSE @ /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/LICENSE.txt as no compatible dataframe file was found.
# [2025-03-25 02:15:26,074][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for demo_subject_id: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/demo_subject_id.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/demo_subject_id.csv
# [2025-03-25 02:15:26,075][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for proc_itemid: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/proc_itemid.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/proc_itemid.csv
# [2025-03-25 02:15:26,076][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for d_labitems_to_loinc: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/d_labitems_to_loinc.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/d_labitems_to_loinc.csv
# [2025-03-25 02:15:26,077][MIMIC_IV_MEDS.pre_MEDS][INFO] - Skipping SHA256SUMS @ /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/SHA256SUMS.txt as no compatible dataframe file was found.
# [2025-03-25 02:15:26,077][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for meas_chartevents_value: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/meas_chartevents_value.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/meas_chartevents_value.csv
# [2025-03-25 02:15:26,078][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for proc_datetimeevents: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/proc_datetimeevents.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/proc_datetimeevents.csv
# [2025-03-25 02:15:26,079][MIMIC_IV_MEDS.pre_MEDS][INFO] - No function needed for waveforms-summary: Copying /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/waveforms-summary.csv to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/waveforms-summary.csv
# [2025-03-25 02:15:26,086][MIMIC_IV_MEDS.pre_MEDS][INFO] - Loading /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/admissions.csv.gz for manipulating other dataframes...
# [2025-03-25 02:15:26,093][MIMIC_IV_MEDS.pre_MEDS][INFO] -   Loaded in 0:00:00.007280
# [2025-03-25 02:15:26,093][MIMIC_IV_MEDS.pre_MEDS][INFO] -   Processing dependent df @ hosp/patients...
# [2025-03-25 02:15:26,093][MIMIC_IV_MEDS.pre_MEDS][INFO] -     Loading /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/patients.csv.gz...
# [2025-03-25 02:15:26,094][MIMIC_IV_MEDS.pre_MEDS][INFO] -     Loaded in 0:00:00.000796
# [2025-03-25 02:15:26,107][MIMIC_IV_MEDS.pre_MEDS][INFO] -     Processed and wrote to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/patients.parquet in 0:00:00.014028
# [2025-03-25 02:15:26,107][MIMIC_IV_MEDS.pre_MEDS][INFO] -   Processing dependent df @ hosp/drgcodes...
# [2025-03-25 02:15:26,107][MIMIC_IV_MEDS.pre_MEDS][INFO] -     Loading /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/drgcodes.csv.gz...
# [2025-03-25 02:15:26,108][MIMIC_IV_MEDS.pre_MEDS][INFO] -     Loaded in 0:00:00.001008
# [2025-03-25 02:15:26,114][MIMIC_IV_MEDS.pre_MEDS][INFO] -     Processed and wrote to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/drgcodes.parquet in 0:00:00.006845
# [2025-03-25 02:15:26,114][MIMIC_IV_MEDS.pre_MEDS][INFO] -   Processing dependent df @ hosp/diagnoses_icd...
# [2025-03-25 02:15:26,115][MIMIC_IV_MEDS.pre_MEDS][INFO] -     Loading /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/raw_input/hosp/diagnoses_icd.csv.gz...
# [2025-03-25 02:15:26,116][MIMIC_IV_MEDS.pre_MEDS][INFO] -     Loaded in 0:00:00.001732
# [2025-03-25 02:15:26,121][MIMIC_IV_MEDS.pre_MEDS][INFO] -     Processed and wrote to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/diagnoses_icd.parquet in 0:00:00.006340
# [2025-03-25 02:15:26,121][MIMIC_IV_MEDS.pre_MEDS][INFO] - Processing hosp/d_icd_diagnoses...
# [2025-03-25 02:15:26,332][MIMIC_IV_MEDS.pre_MEDS][INFO] -   Processed and wrote to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/d_icd_diagnoses.parquet in 0:00:00.210363
# [2025-03-25 02:15:26,333][MIMIC_IV_MEDS.pre_MEDS][INFO] - Processing hosp/d_icd_procedures...
# [2025-03-25 02:15:26,495][MIMIC_IV_MEDS.pre_MEDS][INFO] -   Processed and wrote to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/d_icd_procedures.parquet in 0:00:00.162433
# [2025-03-25 02:15:26,496][MIMIC_IV_MEDS.pre_MEDS][INFO] - Done! All dataframes processed and written to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS
# [2025-03-25 02:15:26,499][MIMIC_IV_MEDS.__main__][INFO] - Running in serial mode as N_WORKERS is not set.
# [2025-03-25 02:15:26,499][MIMIC_IV_MEDS.commands][INFO] - Running command: DATASET_NAME=MIMIC-IV DATASET_VERSION=3.1:0.0.4.dev1+g0dcb6b7.d20250322 EVENT_CONVERSION_CONFIG_FP=/home/justinxu/esgpt/MIMIC_IV_MEDS/src/MIMIC_IV_MEDS/configs/event_configs.yaml PRE_MEDS_DIR=/home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS MEDS_COHORT_DIR=/home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort MEDS_transform-runner --config-path=/home/justinxu/esgpt/MIMIC_IV_MEDS/src/MIMIC_IV_MEDS/configs --config-name=runner pipeline_config_fp=/home/justinxu/esgpt/MIMIC_IV_MEDS/src/MIMIC_IV_MEDS/configs/ETL.yaml ~parallelize 'hydra.searchpath=[pkg://MEDS_transforms.configs]' ++do_overwrite=False ++do_copy=True
# [2025-03-25 02:15:40,969][MIMIC_IV_MEDS.commands][INFO] - Command output:
# [2025-03-25 02:15:26,991][MEDS_transforms.runner][INFO] - Running stage: shard_events
# [2025-03-25 02:15:27,008][MEDS_transforms.runner][INFO] - Running command: MEDS_extract-shard_events --config-dir=/home/justinxu/esgpt/MIMIC_IV_MEDS/src/MIMIC_IV_MEDS/configs --config-name=ETL 'hydra.searchpath=[pkg://MEDS_transforms.configs]' stage=shard_events
# [2025-03-25 02:15:31,741][MEDS_transforms.runner][INFO] - Command output:
# [2025-03-25 02:15:27,573][MEDS_transforms.extract.shard_events][INFO] - Running with config:
# input_dir: ${oc.env:PRE_MEDS_DIR}
# cohort_dir: ${oc.env:MEDS_COHORT_DIR}
# _default_description: 'This is a MEDS pipeline ETL. Please set a more detailed description
#   at the top of your specific pipeline
#
#   configuration file.'
# log_dir: ${stage_cfg.output_dir}/.logs
# do_overwrite: false
# seed: 1
# stages:
# - shard_events
# - split_and_shard_subjects
# - convert_to_sharded_events
# - merge_to_MEDS_cohort
# - extract_code_metadata
# - finalize_MEDS_metadata
# - finalize_MEDS_data
# stage_configs:
#   shard_events:
#     row_chunksize: 200000000
#     infer_schema_length: 999999999
#     data_input_dir: ${input_dir}
#   split_and_shard_subjects:
#     is_metadata: true
#     output_dir: ${cohort_dir}/metadata
#     n_subjects_per_shard: 1000
#     external_splits_json_fp: null
#     split_fracs:
#       train: 0.8
#       tuning: 0.1
#       held_out: 0.1
#   convert_to_sharded_events:
#     do_dedup_text_and_numeric: true
#   merge_to_MEDS_cohort:
#     unique_by: '*'
#     additional_sort_by: null
#   extract_code_metadata:
#     is_metadata: true
#     description_separator: '
#
#       '
#   finalize_MEDS_metadata:
#     is_metadata: true
#     do_retype: true
#   finalize_MEDS_data:
#     do_retype: true
# worker: 0
# polling_time: 300
# stage: shard_events
# stage_cfg: ${oc.create:${populate_stage:${stage}, ${input_dir}, ${cohort_dir}, ${stages},
#   ${stage_configs}}}
# etl_metadata:
#   pipeline_name: ???
#   dataset_name: ${oc.env:DATASET_NAME}
#   dataset_version: ${oc.env:DATASET_VERSION}
#   package_name: ${get_package_name:}
#   package_version: ${get_package_version:}
# etl_metadata.pipeline_name: extract
# description: "This pipeline extracts a dataset in longitudinal, sparse form from an\
#   \ input dataset meeting\nselect criteria and converts them to the MEDS format.\n\
#   \nThis pipeline is for the ${etl_metadata.dataset_name} dataset version ${etl_metadata.dataset_version}.\n\
#   \nKey variables for this pipeline are\n  - `input_dir=$PATH_TO_INPUT_DIR`\n  - `cohort_dir=$PATH_TO_OUTPUT_DIR`.\n\
#   \  - `event_conversion_config_fp=$PATH_TO_EVENT_CONVERSION_CONFIG_FP`\n\nSee the\
#   \ MEDS-Transforms Extract documentation for configuration file details."
# event_conversion_config_fp: ${oc.env:EVENT_CONVERSION_CONFIG_FP}
# shards_map_fp: ${cohort_dir}/metadata/.shards.json
# parallelize:
#   n_workers: ${oc.env:N_WORKERS}
#   launcher: joblib
#
# Stage: shard_events
#
# Stage config:
# row_chunksize: 200000000
# infer_schema_length: 999999999
# data_input_dir: /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS
# is_metadata: false
# metadata_input_dir: /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/metadata
# output_dir: /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events
# reducer_output_dir: null
#
# [2025-03-25 02:15:27,580][MEDS_transforms.extract.shard_events][INFO] - Reading event conversion config from /home/justinxu/esgpt/MIMIC_IV_MEDS/src/MIMIC_IV_MEDS/configs/event_configs.yaml to identify needed columns.
# [2025-03-25 02:15:27,621][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/d_icd_procedures.parquet as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,621][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/d_icd_diagnoses.parquet as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,622][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/lab_itemid_to_loinc.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,622][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/numerics-summary.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,623][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/demo_subject_id.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,623][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/meas_chartevents_value.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,623][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/waveforms-summary.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,623][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/inputevents_to_rxnorm.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,623][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/proc_itemid.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,623][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/meas_chartevents_main.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,624][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/proc_datetimeevents.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,624][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/d_labitems_to_loinc.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,624][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/outputevents_to_loinc.csv as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,624][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/services.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,625][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/microbiologyevents.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,625][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/datetimeevents.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,625][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/d_labitems.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,625][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/emar_detail.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,626][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/prescriptions.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,626][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/d_items.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,627][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/provider.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,627][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/caregiver.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,627][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/poe_detail.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,627][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/ingredientevents.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,628][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/poe.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,628][MEDS_transforms.extract.shard_events][WARNING] - Skipping /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/d_hcpcs.csv.gz as it is not specified in the event conversion configuration.
# [2025-03-25 02:15:27,629][MEDS_transforms.extract.shard_events][INFO] - Starting event sub-sharding. Sub-sharding 16 files:
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/inputevents.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/icustays.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/procedures_icd.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/hcpcsevents.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/pharmacy.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/procedureevents.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/outputevents.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/patients.parquet
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/labevents.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/transfers.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/diagnoses_icd.parquet
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/chartevents.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/emar.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/omr.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/admissions.csv.gz
#   * /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/drgcodes.parquet
# [2025-03-25 02:15:27,632][MEDS_transforms.extract.shard_events][INFO] - Will read raw data from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/$IN_FILE.parquet and write sub-sharded data to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/$IN_FILE/$ROW_START-$ROW_END.parquet
# [2025-03-25 02:15:27,635][MEDS_transforms.extract.shard_events][INFO] - Processing /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/inputevents.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/inputevents.
# [2025-03-25 02:15:27,635][MEDS_transforms.extract.shard_events][INFO] - Performing preliminary read of /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/inputevents.csv.gz to determine row count.
# [2025-03-25 02:15:27,639][MEDS_transforms.extract.shard_events][WARNING] - Reading compressed CSV files may be slow and limit parallelizability.
# [2025-03-25 02:15:27,734][MEDS_transforms.extract.shard_events][INFO] - Read 20404 rows from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/inputevents.csv.gz.
# [2025-03-25 02:15:27,734][MEDS_transforms.extract.shard_events][INFO] - Splitting /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/inputevents.csv.gz into 1 row-chunks of size 200000000.
# [2025-03-25 02:15:27,734][MEDS_transforms.extract.shard_events][INFO] - Writing file 1/1: /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/inputevents.csv.gz row-chunk [0-20404) to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/inputevents/[0-20404).parquet.
# [2025-03-25 02:15:27,738][MEDS_transforms.mapreduce.utils][INFO] - Registered lock at 2025-03-25 02:15:27.738354. Double checking no earlier locks have been registered.
# [2025-03-25 02:15:27,739][MEDS_transforms.mapreduce.utils][INFO] - Reading input dataframe from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/inputevents.csv.gz
# [2025-03-25 02:15:27,740][MEDS_transforms.extract.shard_events][WARNING] - Reading compressed CSV files may be slow and limit parallelizability.
# [2025-03-25 02:15:27,821][MEDS_transforms.mapreduce.utils][INFO] - Read dataset
# [2025-03-25 02:15:27,821][MEDS_transforms.mapreduce.utils][INFO] - Writing final output to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/inputevents/[0-20404).parquet
# [2025-03-25 02:15:28,000][MEDS_transforms.mapreduce.utils][INFO] - Succeeded in 0:00:00.262334
# [2025-03-25 02:15:28,000][MEDS_transforms.mapreduce.utils][INFO] - Leaving cache directory /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/inputevents/.[0-20404).parquet_cache, but clearing lock at /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/inputevents/.[0-20404).parquet_cache/locks/2025-03-25T02:15:27.738354.json
# [2025-03-25 02:15:28,009][MEDS_transforms.extract.shard_events][INFO] - Processing /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/icustays.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/icustays.
# [2025-03-25 02:15:28,009][MEDS_transforms.extract.shard_events][INFO] - Performing preliminary read of /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/icustays.csv.gz to determine row count.
# [2025-03-25 02:15:28,012][MEDS_transforms.extract.shard_events][WARNING] - Reading compressed CSV files may be slow and limit parallelizability.
# [2025-03-25 02:15:28,018][MEDS_transforms.extract.shard_events][INFO] - Read 140 rows from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/icustays.csv.gz.
# [2025-03-25 02:15:28,018][MEDS_transforms.extract.shard_events][INFO] - Splitting /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/icustays.csv.gz into 1 row-chunks of size 200000000.
# [2025-03-25 02:15:28,018][MEDS_transforms.extract.shard_events][INFO] - Writing file 1/1: /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/icustays.csv.gz row-chunk [0-140) to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/icustays/[0-140).parquet.
# [2025-03-25 02:15:28,022][MEDS_transforms.mapreduce.utils][INFO] - Registered lock at 2025-03-25 02:15:28.022238. Double checking no earlier locks have been registered.
# [2025-03-25 02:15:28,022][MEDS_transforms.mapreduce.utils][INFO] - Reading input dataframe from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/icu/icustays.csv.gz
# [2025-03-25 02:15:28,022][MEDS_transforms.extract.shard_events][WARNING] - Reading compressed CSV files may be slow and limit parallelizability.
# [2025-03-25 02:15:28,023][MEDS_transforms.mapreduce.utils][INFO] - Read dataset
# [2025-03-25 02:15:28,023][MEDS_transforms.mapreduce.utils][INFO] - Writing final output to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/icustays/[0-140).parquet
# [2025-03-25 02:15:28,026][MEDS_transforms.mapreduce.utils][INFO] - Succeeded in 0:00:00.003793
# [2025-03-25 02:15:28,026][MEDS_transforms.mapreduce.utils][INFO] - Leaving cache directory /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/icustays/.[0-140).parquet_cache, but clearing lock at /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/icu/icustays/.[0-140).parquet_cache/locks/2025-03-25T02:15:28.022238.json
# [2025-03-25 02:15:28,029][MEDS_transforms.extract.shard_events][INFO] - Processing /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/procedures_icd.csv.gz to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/hosp/procedures_icd.
# [2025-03-25 02:15:28,029][MEDS_transforms.extract.shard_events][INFO] - Performing preliminary read of /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/procedures_icd.csv.gz to determine row count.
# [2025-03-25 02:15:28,032][MEDS_transforms.extract.shard_events][WARNING] - Reading compressed CSV files may be slow and limit parallelizability.
# [2025-03-25 02:15:28,034][MEDS_transforms.extract.shard_events][INFO] - Read 722 rows from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/procedures_icd.csv.gz.
# [2025-03-25 02:15:28,034][MEDS_transforms.extract.shard_events][INFO] - Splitting /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/procedures_icd.csv.gz into 1 row-chunks of size 200000000.
# [2025-03-25 02:15:28,034][MEDS_transforms.extract.shard_events][INFO] - Writing file 1/1: /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/procedures_icd.csv.gz row-chunk [0-722) to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/shard_events/hosp/procedures_icd/[0-722).parquet.
# [2025-03-25 02:15:28,037][MEDS_transforms.mapreduce.utils][INFO] - Registered lock at 2025-03-25 02:15:28.037385. Double checking no earlier locks have been registered.
# [2025-03-25 02:15:28,037][MEDS_transforms.mapreduce.utils][INFO] - Reading input dataframe from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/pre_MEDS/hosp/procedures_icd.csv.gz
# [2025-03-25 02:15:28,037][MEDS_transforms.extract.shard_events][WARNING] - Reading compressed CSV files may be slow and limit parallelizability.
# [2025-03-25 02:15:28,038][MEDS_transforms.mapreduce.utils][INFO] - Read dataset
# ...
# [2025-03-25 02:15:38,353][MEDS_transforms.mapreduce.utils][INFO] - Read dataset
# [2025-03-25 02:15:38,356][MEDS_transforms.extract.extract_code_metadata][WARNING] - Metadata column 'description' must be of type String. Casting.
# [2025-03-25 02:15:38,356][MEDS_transforms.extract.extract_code_metadata][WARNING] - Metadata column 'parent_codes' must be of type List(String). Casting.
# [2025-03-25 02:15:38,358][MEDS_transforms.extract.extract_code_metadata][WARNING] - Metadata column 'description' must be of type String. Casting.
# [2025-03-25 02:15:38,358][MEDS_transforms.extract.extract_code_metadata][WARNING] - Metadata column 'parent_codes' must be of type List(String). Casting.
# [2025-03-25 02:15:38,359][MEDS_transforms.mapreduce.utils][INFO] - Writing final output to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/extract_code_metadata/proc_datetimeevents.parquet
# [2025-03-25 02:15:38,365][MEDS_transforms.mapreduce.utils][INFO] - Succeeded in 0:00:00.012986
# [2025-03-25 02:15:38,365][MEDS_transforms.mapreduce.utils][INFO] - Leaving cache directory /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/extract_code_metadata/.proc_datetimeevents.parquet_cache, but clearing lock at /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/extract_code_metadata/.proc_datetimeevents.parquet_cache/locks/2025-03-25T02:15:38.352717.json
# [2025-03-25 02:15:38,365][MEDS_transforms.extract.extract_code_metadata][INFO] - Extracted metadata for all events. Merging.
# [2025-03-25 02:15:38,366][MEDS_transforms.extract.extract_code_metadata][INFO] - Starting reduction process
# [2025-03-25 02:15:38,366][MEDS_transforms.extract.extract_code_metadata][INFO] - All map shards complete! Starting code metadata reduction computation.
# [2025-03-25 02:15:38,398][MEDS_transforms.extract.extract_code_metadata][INFO] - Collected metadata for 2661 unique codes among 42898 total observations.
# [2025-03-25 02:15:38,479][MEDS_transforms.extract.extract_code_metadata][INFO] - Finished reduction in 0:00:00.113776
#
# [2025-03-25 02:15:38,557][MEDS_transforms.runner][INFO] - Command error:
# /home/justinxu/miniconda3/envs/meds/lib/python3.12/site-packages/MEDS_transforms/extract/extract_code_metadata.py:186: PerformanceWarning: Resolving the schema of a LazyFrame is a potentially expensive operation. Use `LazyFrame.collect_schema()` to get the schema without this warning.
#   if metadata_df.schema[mandatory_col] is not mandatory_type:
# /home/justinxu/miniconda3/envs/meds/lib/python3.12/site-packages/MEDS_transforms/extract/extract_code_metadata.py:186: PerformanceWarning: Resolving the schema of a LazyFrame is a potentially expensive operation. Use `LazyFrame.collect_schema()` to get the schema without this warning.
#   if metadata_df.schema[mandatory_col] is not mandatory_type:
#
# [2025-03-25 02:15:38,557][MEDS_transforms.runner][INFO] - Running stage: finalize_MEDS_metadata
# [2025-03-25 02:15:38,599][MEDS_transforms.runner][INFO] - Running command: MEDS_extract-finalize_MEDS_metadata --config-dir=/home/justinxu/esgpt/MIMIC_IV_MEDS/src/MIMIC_IV_MEDS/configs --config-name=ETL 'hydra.searchpath=[pkg://MEDS_transforms.configs]' stage=finalize_MEDS_metadata
# [2025-03-25 02:15:39,589][MEDS_transforms.runner][INFO] - Command output:
# [2025-03-25 02:15:39,190][MEDS_transforms.utils][INFO] - Running finalize_MEDS_metadata with the following configuration:
# input_dir: ${oc.env:PRE_MEDS_DIR}
# cohort_dir: ${oc.env:MEDS_COHORT_DIR}
# _default_description: 'This is a MEDS pipeline ETL. Please set a more detailed description
#   at the top of your specific pipeline
#
#   configuration file.'
# log_dir: ${stage_cfg.output_dir}/.logs
# do_overwrite: false
# seed: 1
# stages:
# - shard_events
# - split_and_shard_subjects
# - convert_to_sharded_events
# - merge_to_MEDS_cohort
# - extract_code_metadata
# - finalize_MEDS_metadata
# - finalize_MEDS_data
# stage_configs:
#   shard_events:
#     row_chunksize: 200000000
#     infer_schema_length: 999999999
#     data_input_dir: ${input_dir}
#   split_and_shard_subjects:
#     is_metadata: true
#     output_dir: ${cohort_dir}/metadata
#     n_subjects_per_shard: 1000
#     external_splits_json_fp: null
#     split_fracs:
#       train: 0.8
#       tuning: 0.1
#       held_out: 0.1
#   convert_to_sharded_events:
#     do_dedup_text_and_numeric: true
#   merge_to_MEDS_cohort:
#     unique_by: '*'
#     additional_sort_by: null
#   extract_code_metadata:
#     is_metadata: true
#     description_separator: '
#
#       '
#   finalize_MEDS_metadata:
#     is_metadata: true
#     do_retype: true
#   finalize_MEDS_data:
#     do_retype: true
# worker: 0
# polling_time: 300
# stage: finalize_MEDS_metadata
# stage_cfg: ${oc.create:${populate_stage:${stage}, ${input_dir}, ${cohort_dir}, ${stages},
#   ${stage_configs}}}
# etl_metadata:
#   pipeline_name: ???
#   dataset_name: ${oc.env:DATASET_NAME}
#   dataset_version: ${oc.env:DATASET_VERSION}
#   package_name: ${get_package_name:}
#   package_version: ${get_package_version:}
# etl_metadata.pipeline_name: extract
# description: "This pipeline extracts a dataset in longitudinal, sparse form from an\
#   \ input dataset meeting\nselect criteria and converts them to the MEDS format.\n\
#   \nThis pipeline is for the ${etl_metadata.dataset_name} dataset version ${etl_metadata.dataset_version}.\n\
#   \nKey variables for this pipeline are\n  - `input_dir=$PATH_TO_INPUT_DIR`\n  - `cohort_dir=$PATH_TO_OUTPUT_DIR`.\n\
#   \  - `event_conversion_config_fp=$PATH_TO_EVENT_CONVERSION_CONFIG_FP`\n\nSee the\
#   \ MEDS-Transforms Extract documentation for configuration file details."
# event_conversion_config_fp: ${oc.env:EVENT_CONVERSION_CONFIG_FP}
# shards_map_fp: ${cohort_dir}/metadata/.shards.json
# parallelize:
#   n_workers: ${oc.env:N_WORKERS}
#   launcher: joblib
#
# [2025-03-25 02:15:39,220][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Validating code metadata
# [2025-03-25 02:15:39,220][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Reading code metadata from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/extract_code_metadata/codes.parquet
# [2025-03-25 02:15:39,459][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Writing finalized metadata df to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/metadata/codes.parquet
# [2025-03-25 02:15:39,473][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Creating dataset metadata
# [2025-03-25 02:15:39,477][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Writing finalized dataset metadata to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/metadata/dataset.json
# [2025-03-25 02:15:39,478][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Creating subject splits from {str(shards_map_fp.resolve())}
# [2025-03-25 02:15:39,478][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Split train has 80 subjects
# [2025-03-25 02:15:39,478][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Split tuning has 10 subjects
# [2025-03-25 02:15:39,478][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Split held_out has 10 subjects
# [2025-03-25 02:15:39,478][MEDS_transforms.extract.finalize_MEDS_metadata][INFO] - Writing finalized subject splits to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/metadata/subject_splits.parquet
#
# [2025-03-25 02:15:39,589][MEDS_transforms.runner][INFO] - Command error:
#
# [2025-03-25 02:15:39,590][MEDS_transforms.runner][INFO] - Running stage: finalize_MEDS_data
# [2025-03-25 02:15:39,597][MEDS_transforms.runner][INFO] - Running command: MEDS_extract-finalize_MEDS_data --config-dir=/home/justinxu/esgpt/MIMIC_IV_MEDS/src/MIMIC_IV_MEDS/configs --config-name=ETL 'hydra.searchpath=[pkg://MEDS_transforms.configs]' stage=finalize_MEDS_data
# [2025-03-25 02:15:40,893][MEDS_transforms.runner][INFO] - Command output:
# [2025-03-25 02:15:40,147][MEDS_transforms.utils][INFO] - Running finalize_MEDS_data with the following configuration:
# input_dir: ${oc.env:PRE_MEDS_DIR}
# cohort_dir: ${oc.env:MEDS_COHORT_DIR}
# _default_description: 'This is a MEDS pipeline ETL. Please set a more detailed description
#   at the top of your specific pipeline
#
#   configuration file.'
# log_dir: ${stage_cfg.output_dir}/.logs
# do_overwrite: false
# seed: 1
# stages:
# - shard_events
# - split_and_shard_subjects
# - convert_to_sharded_events
# - merge_to_MEDS_cohort
# - extract_code_metadata
# - finalize_MEDS_metadata
# - finalize_MEDS_data
# stage_configs:
#   shard_events:
#     row_chunksize: 200000000
#     infer_schema_length: 999999999
#     data_input_dir: ${input_dir}
#   split_and_shard_subjects:
#     is_metadata: true
#     output_dir: ${cohort_dir}/metadata
#     n_subjects_per_shard: 1000
#     external_splits_json_fp: null
#     split_fracs:
#       train: 0.8
#       tuning: 0.1
#       held_out: 0.1
#   convert_to_sharded_events:
#     do_dedup_text_and_numeric: true
#   merge_to_MEDS_cohort:
#     unique_by: '*'
#     additional_sort_by: null
#   extract_code_metadata:
#     is_metadata: true
#     description_separator: '
#
#       '
#   finalize_MEDS_metadata:
#     is_metadata: true
#     do_retype: true
#   finalize_MEDS_data:
#     do_retype: true
# worker: 0
# polling_time: 300
# stage: finalize_MEDS_data
# stage_cfg: ${oc.create:${populate_stage:${stage}, ${input_dir}, ${cohort_dir}, ${stages},
#   ${stage_configs}}}
# etl_metadata:
#   pipeline_name: ???
#   dataset_name: ${oc.env:DATASET_NAME}
#   dataset_version: ${oc.env:DATASET_VERSION}
#   package_name: ${get_package_name:}
#   package_version: ${get_package_version:}
# etl_metadata.pipeline_name: extract
# description: "This pipeline extracts a dataset in longitudinal, sparse form from an\
#   \ input dataset meeting\nselect criteria and converts them to the MEDS format.\n\
#   \nThis pipeline is for the ${etl_metadata.dataset_name} dataset version ${etl_metadata.dataset_version}.\n\
#   \nKey variables for this pipeline are\n  - `input_dir=$PATH_TO_INPUT_DIR`\n  - `cohort_dir=$PATH_TO_OUTPUT_DIR`.\n\
#   \  - `event_conversion_config_fp=$PATH_TO_EVENT_CONVERSION_CONFIG_FP`\n\nSee the\
#   \ MEDS-Transforms Extract documentation for configuration file details."
# event_conversion_config_fp: ${oc.env:EVENT_CONVERSION_CONFIG_FP}
# shards_map_fp: ${cohort_dir}/metadata/.shards.json
# parallelize:
#   n_workers: ${oc.env:N_WORKERS}
#   launcher: joblib
#
# [2025-03-25 02:15:40,199][MEDS_transforms.mapreduce.utils][INFO] - Mapping computation over a maximum of 3 shards
# [2025-03-25 02:15:40,211][MEDS_transforms.mapreduce.mapper][INFO] - Processing /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/merge_to_MEDS_cohort/held_out/0.parquet into /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/held_out/0.parquet
# [2025-03-25 02:15:40,212][MEDS_transforms.mapreduce.utils][INFO] - Registered lock at 2025-03-25 02:15:40.212381. Double checking no earlier locks have been registered.
# [2025-03-25 02:15:40,213][MEDS_transforms.mapreduce.utils][INFO] - Reading input dataframe from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/merge_to_MEDS_cohort/held_out/0.parquet
# [2025-03-25 02:15:40,213][MEDS_transforms.mapreduce.utils][INFO] - Read dataset
# [2025-03-25 02:15:40,276][MEDS_transforms.mapreduce.utils][INFO] - Writing final output to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/held_out/0.parquet
# [2025-03-25 02:15:40,297][MEDS_transforms.mapreduce.utils][INFO] - Succeeded in 0:00:00.084881
# [2025-03-25 02:15:40,297][MEDS_transforms.mapreduce.utils][INFO] - Leaving cache directory /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/held_out/.0.parquet_cache, but clearing lock at /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/held_out/.0.parquet_cache/locks/2025-03-25T02:15:40.212381.json
# [2025-03-25 02:15:40,297][MEDS_transforms.mapreduce.mapper][INFO] - Processing /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/merge_to_MEDS_cohort/tuning/0.parquet into /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/tuning/0.parquet
# [2025-03-25 02:15:40,298][MEDS_transforms.mapreduce.utils][INFO] - Registered lock at 2025-03-25 02:15:40.298140. Double checking no earlier locks have been registered.
# [2025-03-25 02:15:40,298][MEDS_transforms.mapreduce.utils][INFO] - Reading input dataframe from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/merge_to_MEDS_cohort/tuning/0.parquet
# [2025-03-25 02:15:40,298][MEDS_transforms.mapreduce.utils][INFO] - Read dataset
# [2025-03-25 02:15:40,308][MEDS_transforms.mapreduce.utils][INFO] - Writing final output to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/tuning/0.parquet
# [2025-03-25 02:15:40,338][MEDS_transforms.mapreduce.utils][INFO] - Succeeded in 0:00:00.040194
# [2025-03-25 02:15:40,338][MEDS_transforms.mapreduce.utils][INFO] - Leaving cache directory /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/tuning/.0.parquet_cache, but clearing lock at /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/tuning/.0.parquet_cache/locks/2025-03-25T02:15:40.298140.json
# [2025-03-25 02:15:40,338][MEDS_transforms.mapreduce.mapper][INFO] - Processing /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/merge_to_MEDS_cohort/train/0.parquet into /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/train/0.parquet
# [2025-03-25 02:15:40,339][MEDS_transforms.mapreduce.utils][INFO] - Registered lock at 2025-03-25 02:15:40.339173. Double checking no earlier locks have been registered.
# [2025-03-25 02:15:40,339][MEDS_transforms.mapreduce.utils][INFO] - Reading input dataframe from /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/merge_to_MEDS_cohort/train/0.parquet
# [2025-03-25 02:15:40,339][MEDS_transforms.mapreduce.utils][INFO] - Read dataset
# [2025-03-25 02:15:40,447][MEDS_transforms.mapreduce.utils][INFO] - Writing final output to /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/train/0.parquet
# [2025-03-25 02:15:40,791][MEDS_transforms.mapreduce.utils][INFO] - Succeeded in 0:00:00.452729
# [2025-03-25 02:15:40,792][MEDS_transforms.mapreduce.utils][INFO] - Leaving cache directory /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/train/.0.parquet_cache, but clearing lock at /home/justinxu/esgpt/medical-event-data-standard.github.io/tutorial_notebooks/tutorial-basics/demo_output/meds/MEDS_cohort/data/train/.0.parquet_cache/locks/2025-03-25T02:15:40.339173.json
# [2025-03-25 02:15:40,797][MEDS_transforms.mapreduce.mapper][INFO] - Finished mapping in 0:00:00.624569
#
# [2025-03-25 02:15:40,893][MEDS_transforms.runner][INFO] - Command error:

# %% [markdown]
# ## Extracting the Prediction Task

# %% [markdown]
# ### In-ICU Mortality
#
# For this tutorial, we'll extract a cohort for a basic in-ICU mortality prediction task. Let's first define our
# task parameters.
#
# Our goal is to predict the mortality outcome for a patient's entire ICU admission using historical patient
# data plus the initial 24 hours of data after the patient was first admitted into the ICU.
#
# Suppose we only want to consider patients whose ICU admission was longer than 48 hours. As such, patients who
# died or are discharged from the ICU within 48 hours of being admitted are excluded.
#
# **Note:** This task is distinct from in-***hospital*** mortality,  ***30-day*** mortality, or ***imminent***
# mortality.

# %% [markdown]
# We can visualize this task as a series of inter-related windows using the below timeline:
#
# ![In-hospital Mortality](../../static/img/icu_mortality.svg)

# %% [markdown]
# - The "blue" region represents the "**input**" data window. All historical patient data up to and including the first 24 hours of a patient's ICU admission will serve as input into a downstream model.
# - The "red" bar represents the ICU admission, and would "**trigger**" the start of our prediction task.
# - The "yellow" region represents the first 48 hours of a patient's ICU admission, and we stipulate a "**gap**" whereby the patient must not have died or been discharged during that period.
# - The "magenta" region represents our prediction "target" window which can be of varying length, as it ends whenever a patient dies or is discharged.

# %% [markdown]
# ### ACES Configuration File

# %% [markdown]
# ACES uses a configuration language to capture cohort and task definitions. Details about this configuration language is available in the [ACES Documentation](https://eventstreamaces.readthedocs.io/en/latest/readme.html#task-configuration-file).
#
# Let's walkthrough the construction of an ACES configuration file. At a minimum, the most basic configuration file would contain the `predicates`, `trigger`, and `windows` sections.

# %% [markdown]
# #### Predicates
#
# To capture our task definition, we must first define at least three simple concepts, or ACES plain [predicates](https://eventstreamaces.readthedocs.io/en/latest/notebooks/predicates.html), for our demo dataset.
#
# For starters, as we are specifically interested in mortality "in the ICU", an `ICU admission` and a `ICU discharge` predicate would be needed to represent events where patients are officially admitted to the ICU and where patients are officially discharged. We also need the `death` predicate to capture death events so we can accurately capture the mortality component.
#
# To define predicates, we would need to find how these concepts are represented in our dataset. For MIMIC-IV-Demo in MEDS format, these concepts can be found using simple regular expressions:
#
# ```yaml
# predicates:
#   icu_admission:
#     code: { regex: "^ICU_ADMISSION//.*" }
#   icu_discharge:
#     code: { regex: "^ICU_DISCHARGE//.*" }
#   death:
#     code: { regex: "MEDS_DEATH.*" }
# ```
#
# Since patients can either die or be discharged from the ICU, we may also create a more complex concept, or an ACES derived predicate, by joining the above simple concepts using an `OR` relationship:
# ```yaml
# predicates:
#   discharge_or_death:
#     expr: or(icu_discharge, death)
# ```

# %% [markdown]
# #### Trigger
#
# As mentioned above, a patient's admission into the ICU triggers our prediction task. A designated field defines this ACES [trigger](https://eventstreamaces.readthedocs.io/en/latest/readme.html#trigger-event), and its value must always be one of the specified predicates. For our task, this predicate would be `icu_admission`:
#
# ```yaml
# trigger: icu_admission
# ```

# %% [markdown]
# #### Windows
#
# The windows section contains the remaining three windows we defined previously - `input`, `gap`, and `target`.
#
# For details on the configuration language syntax for windows, please see the [documentation](https://eventstreamaces.readthedocs.io/en/latest/readme.html#windows). Briefly, certain fields are present in all windows:
#
# ```yaml
# windows:
#   window_name:
#     start:
#     end:
#     start_inclusive:
#     end_inclusive:
# ```
# However, some windows also have optional parameters, such as the `has` field, which captures predicate count criteria for that particular window:
# ```yaml
# windows:
#   window_name:
#     ...
#     has:
#       predicate_a: (min, max)
#       predicate_b: (min, max)
#       ...
# ```

# %% [markdown]
# For our in-ICU mortality prediction task, we can define:
#
# 1. `input`, which begins at the start of a patient's record (ie., `null`), and ends 24 hours past `trigger` (ie., `icu_admission`). As we'd like to include the events specified at both the start and end of `input`, if present, we can set both `start_inclusive` and `end_inclusive` as `True`.
#
#     **Note**: Since we'd like our model to make a prediction at the end of `input`, we can set `index_timestamp` to be `end`, which corresponds to the timestamp of `trigger + 24h`.
#
#     ```yaml
#     windows:
#       input:
#         start: null
#         end: trigger + 24h
#         start_inclusive: True
#         end_inclusive: True
#         index_timestamp: end
#     ```
#
# 2. `gap`, which also begins at `trigger`, and ends 48 hours after. As we have included the left boundary event in `trigger` (ie., `icu_admission`), it would be reasonable to **not** include it again as it should not play a role in `gap`. As such, we set `start_inclusive` to `False`. As we'd like our ICU admission to be at least 48 hours long, we can place constraints specifying that there cannot be any additional `icu_admission`, `icu_discharge`, or `death` in `gap`.
#
#     ```yaml
#     windows:
#       gap:
#         start: trigger
#         end: start + 48h
#         start_inclusive: False
#         end_inclusive: True
#         has:
#           icu_admission: (None, 0)
#           discharge_or_death: (None, 0)
#     ```
#
# 3. `target`, which begins at the end of `gap`, and ends at the next discharge or death event (ie., `discharge_or_death` predicate). We can use this arrow notation which ACES recognizes as event references (ie., `->` and `<-`; see [Time Range Fields](https://eventstreamaces.readthedocs.io/en/latest/technical.html#time-range-fields)). In our case, we end `target` at the next `discharge_or_death`. Similarly, as we included the event at the end of `gap`, if any, already in `gap`, we can set `start_inclusive` to `False`.
#
#     **Note**: Since we'd like to make a binary mortality prediction, we can extract the `death` predicate as a label from `target`, by specifying the `label` field to be `death`.
#
#     ```yaml
#     windows:
#       target:
#         start: gap.end
#         end: start -> discharge_or_death
#         start_inclusive: False
#         end_inclusive: True
#         label: death
#     ```

# %% [markdown]
# Now, we can put all the components together to form a complete ACES configuration file that captures everything we need for our cohort and task:
#
# ```yaml
# predicates:
#   icu_admission:
#     code: { regex: "^ICU_ADMISSION//.*" }
#   icu_discharge:
#     code: { regex: "^ICU_DISCHARGE//.*" }
#   death:
#     code: { regex: "MEDS_DEATH.*" }
#   discharge_or_death:
#     expr: or(icu_discharge, death)
#
# trigger: icu_admission
#
# windows:
#   input:
#     start: null
#     end: trigger + 24h
#     start_inclusive: True
#     end_inclusive: True
#     index_timestamp: end
#   gap:
#     start: trigger
#     end: start + 48h
#     start_inclusive: False
#     end_inclusive: True
#     has:
#       icu_admission: (None, 0)
#       discharge_or_death: (None, 0)
#   target:
#     start: gap.end
#     end: start -> discharge_or_death
#     start_inclusive: False
#     end_inclusive: True
#     label: death
# ```

# %% [markdown]
# ### End-to-End Extraction using the ACES CLI

# %% [markdown]
# With the configuration file ready, extracting the cohort from our demo dataset is extremely straightforward. All we need to do is run a simple command-line tool.

# %%
in_icu = """
predicates:
  icu_admission:
    code: { regex: "^ICU_ADMISSION//.*" }
  icu_discharge:
    code: { regex: "^ICU_DISCHARGE//.*" }
  death:
    code: { regex: "MEDS_DEATH.*" }
  discharge_or_death:
    expr: or(icu_discharge, death)

trigger: icu_admission

windows:
  input:
    start: null
    end: trigger + 24h
    start_inclusive: True
    end_inclusive: True
    index_timestamp: end
  gap:
    start: trigger
    end: start + 48h
    start_inclusive: False
    end_inclusive: True
    has:
      icu_admission: (None, 0)
      discharge_or_death: (None, 0)
  target:
    start: gap.end
    end: start -> discharge_or_death
    start_inclusive: False
    end_inclusive: True
    label: death
"""

# %% [markdown]
# Let's save the final configuration file in a YAML file in our demo directory:

# %%
COHORT_NAME = "in_icu"
COHORT_DIR = DEMO_DIR / "cohorts"
COHORT_DIR.mkdir(parents=True, exist_ok=True)

with open(COHORT_DIR / f"{COHORT_NAME}.yaml", "w") as f:
    f.write(in_icu)

# %% [markdown]
# We can now set some variables for CLI parameters. For more information on CLI arguments, please see the [documentation](https://eventstreamaces.readthedocs.io/en/latest/usage.html#detailed-instructions), including [instructions](https://eventstreamaces.readthedocs.io/en/latest/usage.html#multiple-shards) for using `expand_shards` for simultaneous extraction of cohorts over multiple MEDS shards.

# %%
DATA_STANDARD = "meds"
DATA_ROOT = OUTPUT_DIR / "MEDS_cohort/data/"
DATA_SHARD = "$(expand_shards train/1 tuning/1 held_out/1)"

# %%
# !aces-cli \
    cohort_name=$COHORT_NAME \
    cohort_dir=$COHORT_DIR \
    data=sharded \
    data.standard=$DATA_STANDARD \
    data.root=$DATA_ROOT \
    data.shard=$DATA_SHARD -m
# Out:
# [2025-03-25 02:15:42,893][HYDRA] Launching 3 jobs locally
# [2025-03-25 02:15:42,893][HYDRA] 	#0 : cohort_name=in_icu cohort_dir=demo_output/cohorts data=sharded data.standard=meds data.root=demo_output/meds/MEDS_cohort/data data.shard=train/0
# 2025-03-25 02:15:43.313 | INFO     | aces.__main__:main:149 - Loading config from 'demo_output/cohorts/in_icu.yaml'
# 2025-03-25 02:15:43.318 | INFO     | aces.config:load:1341 - Parsing windows...
# 2025-03-25 02:15:43.318 | INFO     | aces.config:load:1350 - Parsing trigger event...
# 2025-03-25 02:15:43.318 | INFO     | aces.config:load:1392 - Parsing predicates...
# 2025-03-25 02:15:43.323 | INFO     | aces.__main__:main:159 - Attempting to get predicates dataframe given:
# standard: meds
# ts_format: '%m/%d/%Y %H:%M'
# root: demo_output/meds/MEDS_cohort/data
# shard: train/0
# path: ${data.root}/${data.shard}.parquet
# _prefix: /${data.shard}
#
# 2025-03-25 02:15:43.324 | INFO     | aces.predicates:generate_plain_predicates_from_meds:269 - Loading MEDS data...
# 2025-03-25 02:15:43.367 | INFO     | aces.predicates:generate_plain_predicates_from_meds:273 - Generating plain predicate columns...
# 2025-03-25 02:15:43.395 | INFO     | aces.predicates:generate_plain_predicates_from_meds:277 - Added predicate column 'icu_admission'.
# 2025-03-25 02:15:43.424 | INFO     | aces.predicates:generate_plain_predicates_from_meds:277 - Added predicate column 'icu_discharge'.
# 2025-03-25 02:15:43.464 | INFO     | aces.predicates:generate_plain_predicates_from_meds:277 - Added predicate column 'death'.
# 2025-03-25 02:15:43.464 | INFO     | aces.predicates:generate_plain_predicates_from_meds:280 - Cleaning up predicates dataframe...
# 2025-03-25 02:15:43.505 | INFO     | aces.predicates:get_predicates_df:703 - Loaded plain predicates. Generating derived predicate columns...
# 2025-03-25 02:15:43.506 | INFO     | aces.predicates:get_predicates_df:717 - Added predicate column 'discharge_or_death'.
# 2025-03-25 02:15:43.506 | INFO     | aces.predicates:get_predicates_df:724 - Generating special predicate columns...
# 2025-03-25 02:15:43.506 | INFO     | aces.query:query:76 - Checking if '(subject_id, timestamp)' columns are unique...
# 2025-03-25 02:15:43.509 | INFO     | aces.utils:log_tree:67 -
# trigger
# ┣━━ input.end
# ┃   ┗━━ input.start
# ┗━━ gap.end
#     ┗━━ target.end
#
# 2025-03-25 02:15:43.510 | INFO     | aces.query:query:85 - Beginning query...
# 2025-03-25 02:15:43.510 | INFO     | aces.query:query:92 - No static variable criteria specified, removing all rows with null timestamps...
# 2025-03-25 02:15:43.511 | INFO     | aces.query:query:99 - Identifying possible trigger nodes based on the specified trigger event...
# 2025-03-25 02:15:43.511 | INFO     | aces.constraints:check_constraints:110 - Excluding 72,774 rows as they failed to satisfy '1 <= icu_admission <= None'.
# 2025-03-25 02:15:43.512 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'input.end'...
# 2025-03-25 02:15:43.596 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'input.start'...
# 2025-03-25 02:15:43.707 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'gap.end'...
# 2025-03-25 02:15:43.770 | INFO     | aces.constraints:check_constraints:110 - Excluding 2 rows as they failed to satisfy 'None <= icu_admission <= 0'.
# 2025-03-25 02:15:43.771 | INFO     | aces.constraints:check_constraints:110 - Excluding 53 rows as they failed to satisfy 'None <= discharge_or_death <= 0'.
# 2025-03-25 02:15:43.772 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'target.end'...
# 2025-03-25 02:15:43.858 | INFO     | aces.query:query:114 - Done. 60 valid rows returned corresponding to 47 subjects.
# 2025-03-25 02:15:43.858 | INFO     | aces.query:query:129 - Extracting label 'death' from window 'target'...
# 2025-03-25 02:15:43.858 | INFO     | aces.query:query:150 - Setting index timestamp as 'end' of window 'input'...
# 2025-03-25 02:15:43.862 | WARNING  | aces.__main__:get_and_validate_label_schema:114 - Output contains columns that are not valid MEDS label columns. For now, we are dropping them.
# If you need these columns, please comment on https://github.com/justin13601/ACES/issues/97
# Columns:
#   - trigger
#   - input.end_summary
#   - input.start_summary
#   - gap.end_summary
#   - target.end_summary
# 2025-03-25 02:15:43.870 | INFO     | aces.__main__:main:191 - Completed in 0:00:00.555944. Results saved to 'demo_output/cohorts/in_icu/train/0.parquet'.
# [2025-03-25 02:15:43,871][HYDRA] 	#1 : cohort_name=in_icu cohort_dir=demo_output/cohorts data=sharded data.standard=meds data.root=demo_output/meds/MEDS_cohort/data data.shard=tuning/0
# 2025-03-25 02:15:44.054 | INFO     | aces.__main__:main:149 - Loading config from 'demo_output/cohorts/in_icu.yaml'
# 2025-03-25 02:15:44.058 | INFO     | aces.config:load:1341 - Parsing windows...
# 2025-03-25 02:15:44.059 | INFO     | aces.config:load:1350 - Parsing trigger event...
# 2025-03-25 02:15:44.059 | INFO     | aces.config:load:1392 - Parsing predicates...
# 2025-03-25 02:15:44.060 | INFO     | aces.__main__:main:159 - Attempting to get predicates dataframe given:
# standard: meds
# ts_format: '%m/%d/%Y %H:%M'
# root: demo_output/meds/MEDS_cohort/data
# shard: tuning/0
# path: ${data.root}/${data.shard}.parquet
# _prefix: /${data.shard}
#
# 2025-03-25 02:15:44.060 | INFO     | aces.predicates:generate_plain_predicates_from_meds:269 - Loading MEDS data...
# 2025-03-25 02:15:44.064 | INFO     | aces.predicates:generate_plain_predicates_from_meds:273 - Generating plain predicate columns...
# 2025-03-25 02:15:44.067 | INFO     | aces.predicates:generate_plain_predicates_from_meds:277 - Added predicate column 'icu_admission'.
# 2025-03-25 02:15:44.070 | INFO     | aces.predicates:generate_plain_predicates_from_meds:277 - Added predicate column 'icu_discharge'.
# 2025-03-25 02:15:44.074 | INFO     | aces.predicates:generate_plain_predicates_from_meds:277 - Added predicate column 'death'.
# 2025-03-25 02:15:44.074 | INFO     | aces.predicates:generate_plain_predicates_from_meds:280 - Cleaning up predicates dataframe...
# 2025-03-25 02:15:44.080 | INFO     | aces.predicates:get_predicates_df:703 - Loaded plain predicates. Generating derived predicate columns...
# 2025-03-25 02:15:44.081 | INFO     | aces.predicates:get_predicates_df:717 - Added predicate column 'discharge_or_death'.
# 2025-03-25 02:15:44.081 | INFO     | aces.predicates:get_predicates_df:724 - Generating special predicate columns...
# 2025-03-25 02:15:44.081 | INFO     | aces.query:query:76 - Checking if '(subject_id, timestamp)' columns are unique...
# 2025-03-25 02:15:44.082 | INFO     | aces.utils:log_tree:67 -
# trigger
# ┣━━ input.end
# ┃   ┗━━ input.start
# ┗━━ gap.end
#     ┗━━ target.end
#
# 2025-03-25 02:15:44.082 | INFO     | aces.query:query:85 - Beginning query...
# 2025-03-25 02:15:44.083 | INFO     | aces.query:query:92 - No static variable criteria specified, removing all rows with null timestamps...
# 2025-03-25 02:15:44.083 | INFO     | aces.query:query:99 - Identifying possible trigger nodes based on the specified trigger event...
# 2025-03-25 02:15:44.083 | INFO     | aces.constraints:check_constraints:110 - Excluding 6,242 rows as they failed to satisfy '1 <= icu_admission <= None'.
# 2025-03-25 02:15:44.084 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'input.end'...
# 2025-03-25 02:15:44.097 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'input.start'...
# 2025-03-25 02:15:44.123 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'gap.end'...
# 2025-03-25 02:15:44.136 | INFO     | aces.constraints:check_constraints:110 - Excluding 0 rows as they failed to satisfy 'None <= icu_admission <= 0'.
# 2025-03-25 02:15:44.136 | INFO     | aces.constraints:check_constraints:110 - Excluding 7 rows as they failed to satisfy 'None <= discharge_or_death <= 0'.
# 2025-03-25 02:15:44.137 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'target.end'...
# 2025-03-25 02:15:44.165 | INFO     | aces.query:query:114 - Done. 8 valid rows returned corresponding to 5 subjects.
# 2025-03-25 02:15:44.165 | INFO     | aces.query:query:129 - Extracting label 'death' from window 'target'...
# 2025-03-25 02:15:44.166 | INFO     | aces.query:query:150 - Setting index timestamp as 'end' of window 'input'...
# 2025-03-25 02:15:44.168 | WARNING  | aces.__main__:get_and_validate_label_schema:114 - Output contains columns that are not valid MEDS label columns. For now, we are dropping them.
# If you need these columns, please comment on https://github.com/justin13601/ACES/issues/97
# Columns:
#   - trigger
#   - input.end_summary
#   - input.start_summary
#   - gap.end_summary
#   - target.end_summary
# 2025-03-25 02:15:44.173 | INFO     | aces.__main__:main:191 - Completed in 0:00:00.117831. Results saved to 'demo_output/cohorts/in_icu/tuning/0.parquet'.
# [2025-03-25 02:15:44,174][HYDRA] 	#2 : cohort_name=in_icu cohort_dir=demo_output/cohorts data=sharded data.standard=meds data.root=demo_output/meds/MEDS_cohort/data data.shard=held_out/0
# 2025-03-25 02:15:44.267 | INFO     | aces.__main__:main:149 - Loading config from 'demo_output/cohorts/in_icu.yaml'
# 2025-03-25 02:15:44.271 | INFO     | aces.config:load:1341 - Parsing windows...
# 2025-03-25 02:15:44.271 | INFO     | aces.config:load:1350 - Parsing trigger event...
# 2025-03-25 02:15:44.271 | INFO     | aces.config:load:1392 - Parsing predicates...
# 2025-03-25 02:15:44.272 | INFO     | aces.__main__:main:159 - Attempting to get predicates dataframe given:
# standard: meds
# ts_format: '%m/%d/%Y %H:%M'
# root: demo_output/meds/MEDS_cohort/data
# shard: held_out/0
# path: ${data.root}/${data.shard}.parquet
# _prefix: /${data.shard}
#
# 2025-03-25 02:15:44.273 | INFO     | aces.predicates:generate_plain_predicates_from_meds:269 - Loading MEDS data...
# 2025-03-25 02:15:44.275 | INFO     | aces.predicates:generate_plain_predicates_from_meds:273 - Generating plain predicate columns...
# 2025-03-25 02:15:44.277 | INFO     | aces.predicates:generate_plain_predicates_from_meds:277 - Added predicate column 'icu_admission'.
# 2025-03-25 02:15:44.279 | INFO     | aces.predicates:generate_plain_predicates_from_meds:277 - Added predicate column 'icu_discharge'.
# 2025-03-25 02:15:44.281 | INFO     | aces.predicates:generate_plain_predicates_from_meds:277 - Added predicate column 'death'.
# 2025-03-25 02:15:44.282 | INFO     | aces.predicates:generate_plain_predicates_from_meds:280 - Cleaning up predicates dataframe...
# 2025-03-25 02:15:44.285 | INFO     | aces.predicates:get_predicates_df:703 - Loaded plain predicates. Generating derived predicate columns...
# 2025-03-25 02:15:44.286 | INFO     | aces.predicates:get_predicates_df:717 - Added predicate column 'discharge_or_death'.
# 2025-03-25 02:15:44.286 | INFO     | aces.predicates:get_predicates_df:724 - Generating special predicate columns...
# 2025-03-25 02:15:44.286 | INFO     | aces.query:query:76 - Checking if '(subject_id, timestamp)' columns are unique...
# 2025-03-25 02:15:44.287 | INFO     | aces.utils:log_tree:67 -
# trigger
# ┣━━ input.end
# ┃   ┗━━ input.start
# ┗━━ gap.end
#     ┗━━ target.end
#
# 2025-03-25 02:15:44.287 | INFO     | aces.query:query:85 - Beginning query...
# 2025-03-25 02:15:44.288 | INFO     | aces.query:query:92 - No static variable criteria specified, removing all rows with null timestamps...
# 2025-03-25 02:15:44.288 | INFO     | aces.query:query:99 - Identifying possible trigger nodes based on the specified trigger event...
# 2025-03-25 02:15:44.288 | INFO     | aces.constraints:check_constraints:110 - Excluding 4,163 rows as they failed to satisfy '1 <= icu_admission <= None'.
# 2025-03-25 02:15:44.289 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'input.end'...
# 2025-03-25 02:15:44.298 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'input.start'...
# 2025-03-25 02:15:44.322 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'gap.end'...
# 2025-03-25 02:15:44.333 | INFO     | aces.constraints:check_constraints:110 - Excluding 0 rows as they failed to satisfy 'None <= icu_admission <= 0'.
# 2025-03-25 02:15:44.333 | INFO     | aces.constraints:check_constraints:110 - Excluding 6 rows as they failed to satisfy 'None <= discharge_or_death <= 0'.
# 2025-03-25 02:15:44.334 | INFO     | aces.extract_subtree:extract_subtree:252 - Summarizing subtree rooted at 'target.end'...
# 2025-03-25 02:15:44.359 | INFO     | aces.query:query:114 - Done. 6 valid rows returned corresponding to 4 subjects.
# 2025-03-25 02:15:44.359 | INFO     | aces.query:query:129 - Extracting label 'death' from window 'target'...
# 2025-03-25 02:15:44.360 | WARNING  | aces.query:query:142 - All labels in the extracted cohort are the same: '0'. This may indicate an issue with the task logic. Please double-check your configuration file if this is not expected.
# 2025-03-25 02:15:44.360 | INFO     | aces.query:query:150 - Setting index timestamp as 'end' of window 'input'...
# 2025-03-25 02:15:44.363 | WARNING  | aces.__main__:get_and_validate_label_schema:114 - Output contains columns that are not valid MEDS label columns. For now, we are dropping them.
# If you need these columns, please comment on https://github.com/justin13601/ACES/issues/97
# Columns:
#   - trigger
#   - input.end_summary
#   - input.start_summary
#   - gap.end_summary
#   - target.end_summary
# 2025-03-25 02:15:44.367 | INFO     | aces.__main__:main:191 - Completed in 0:00:00.099429. Results saved to 'demo_output/cohorts/in_icu/held_out/0.parquet'.

# %% [markdown]
# #### Inspecting Results

# %% [markdown]
# The CLI would output a parquet file for each corresponding data split. Let's examine the output for the train split:

# %%
import pandas as pd
results = pd.read_parquet(COHORT_DIR / COHORT_NAME / "train" / "0.parquet")

# %% [markdown]
# Here is the label distribution of the patients that met our cohort criteria in the train split:

# %%
results['boolean_value'].value_counts()
# Out:
# boolean_value
# False    52
# True      8
# Name: count, dtype: int64

# %% [markdown]
# Recall that our `label` predicate was set to `death` in our configuration file. Thus, we can interpret this as 8 patients who died, and 52 patients who were discharged from the ICU. The full results provide the exact `subject_id` for all patients that meet our cohort criteria, and `prediction_time` corresponds to the `index_timestamp` defined in our configuration file.

# %%
results
# Out:
#     subject_id     prediction_time  boolean_value  integer_value  float_value  \
# 0     10002428 2156-04-13 16:24:18          False            NaN          NaN
# 1     10002428 2156-04-20 18:11:19          False            NaN          NaN
# 2     10002428 2156-05-01 21:53:00          False            NaN          NaN
# 3     10002428 2156-05-12 14:49:34          False            NaN          NaN
# 4     10002495 2141-05-23 20:18:01          False            NaN          NaN
# 5     10003400 2137-02-26 23:37:19          False            NaN          NaN
# 6     10003400 2137-08-11 19:54:51          False            NaN          NaN
# 7     10003400 2137-08-18 17:36:37           True            NaN          NaN
# 8     10004235 2196-02-25 17:07:00          False            NaN          NaN
# 9     10004422 2111-01-18 09:44:50          False            NaN          NaN
# 10    10004720 2186-11-13 19:55:00           True            NaN          NaN
# 11    10004733 2174-12-05 11:28:24          False            NaN          NaN
# 12    10005817 2132-12-16 09:29:01          False            NaN          NaN
# 13    10005817 2135-01-04 21:55:32           True            NaN          NaN
# 14    10005866 2149-10-03 12:48:08          False            NaN          NaN
# 15    10005909 2144-10-30 23:09:03          False            NaN          NaN
# 16    10007058 2167-11-08 20:22:00          False            NaN          NaN
# 17    10007818 2146-06-23 11:46:29           True            NaN          NaN
# 18    10007928 2129-04-07 00:25:00          False            NaN          NaN
# 19    10008454 2110-12-01 17:11:36          False            NaN          NaN
# 20    10009628 2153-09-20 09:54:49          False            NaN          NaN
# 21    10010471 2155-12-03 20:33:00           True            NaN          NaN
# 22    10010867 2147-12-31 09:33:00          False            NaN          NaN
# 23    10012552 2140-03-26 14:37:26          False            NaN          NaN
# 24    10014078 2166-08-23 00:36:00          False            NaN          NaN
# 25    10014354 2148-07-08 15:48:09          False            NaN          NaN
# 26    10015272 2137-06-13 18:37:22          False            NaN          NaN
# 27    10015931 2177-03-25 21:48:07           True            NaN          NaN
# 28    10018081 2133-12-19 17:10:00          False            NaN          NaN
# 29    10018081 2134-08-06 14:53:33          False            NaN          NaN
# 30    10018328 2154-04-25 23:03:44          False            NaN          NaN
# 31    10019003 2153-03-29 02:21:00          False            NaN          NaN
# 32    10019003 2153-04-14 19:45:30          False            NaN          NaN
# 33    10019003 2155-07-11 17:48:57          False            NaN          NaN
# 34    10020187 2169-01-16 04:56:00          False            NaN          NaN
# 35    10020306 2135-01-22 17:01:57          False            NaN          NaN
# 36    10020640 2153-02-14 01:38:00          False            NaN          NaN
# 37    10020944 2131-02-28 16:40:00          False            NaN          NaN
# 38    10021487 2116-12-04 01:02:00          False            NaN          NaN
# 39    10022017 2189-09-11 10:05:24          False            NaN          NaN
# 40    10023117 2171-11-15 10:06:41          False            NaN          NaN
# 41    10023117 2175-03-22 03:20:53          False            NaN          NaN
# 42    10023117 2175-07-07 17:41:00          False            NaN          NaN
# 43    10023239 2137-06-20 19:09:00          False            NaN          NaN
# 44    10023239 2140-10-04 09:07:56          False            NaN          NaN
# 45    10024043 2117-04-12 22:05:00          False            NaN          NaN
# 46    10025612 2125-09-26 13:23:24          False            NaN          NaN
# 47    10027445 2142-08-01 01:41:00          False            NaN          NaN
# 48    10027602 2201-10-31 12:25:00          False            NaN          NaN
# 49    10029291 2123-02-21 04:13:00          False            NaN          NaN
# 50    10029291 2123-02-27 12:12:32          False            NaN          NaN
# 51    10031757 2137-10-16 17:29:21          False            NaN          NaN
# 52    10032725 2143-03-23 06:42:00          False            NaN          NaN
# 53    10035631 2116-02-29 18:43:20          False            NaN          NaN
# 54    10037861 2117-03-15 16:34:58           True            NaN          NaN
# 55    10037975 2185-01-18 19:12:12           True            NaN          NaN
# 56    10038933 2148-09-11 13:19:00          False            NaN          NaN
# 57    10038999 2131-05-23 21:50:33          False            NaN          NaN
# 58    10039708 2140-01-24 18:08:00          False            NaN          NaN
# 59    10040025 2148-01-25 04:50:17          False            NaN          NaN
#
#    categorical_value
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# 5               None
# 6               None
# 7               None
# 8               None
# 9               None
# 10              None
# 11              None
# 12              None
# 13              None
# 14              None
# 15              None
# 16              None
# 17              None
# 18              None
# 19              None
# 20              None
# 21              None
# 22              None
# 23              None
# 24              None
# 25              None
# 26              None
# 27              None
# 28              None
# 29              None
# 30              None
# 31              None
# 32              None
# 33              None
# 34              None
# 35              None
# 36              None
# 37              None
# 38              None
# 39              None
# 40              None
# 41              None
# 42              None
# 43              None
# 44              None
# 45              None
# 46              None
# 47              None
# 48              None
# 49              None
# 50              None
# 51              None
# 52              None
# 53              None
# 54              None
# 55              None
# 56              None
# 57              None
# 58              None
# 59              None
